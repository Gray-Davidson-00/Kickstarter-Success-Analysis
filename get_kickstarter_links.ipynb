# %%
import requests
from bs4 import BeautifulSoup
import re
import csv
from datetime import datetime
import time
import random
import pandas as pd
import pickle

# Source: https://www.kickstarter.com/discover/advanced?sort=end_date

kickstarter_pages = list(range(1, 201)) 
# There are 200 pages of data available, each with 12 results.

# %%
def get_data(pages):
    url = "https://www.kickstarter.com/discover/advanced?woe_id=0&page={}" 
    https://www.kickstarter.com/discover/advanced?raised=0&sort=end_date&seed=2540281&page=1
    find_projects = re.compile(r'www.kickstarter.com/projects/[^",&]+') # Establish our regex
    all_project_links = []
    i = 1
    for page in pages:    
        print('Working on Page: ' + str(i)) # So we can watch it work
        full_url = url.format(page) # Generate the full page URL using page={}
        response = requests.get(full_url) 
        page = response.text
        soup = BeautifulSoup(page,"lxml")
        one_page_project_links = find_projects.findall(soup.prettify()) # Apply the regex to pull the links we want
        one_page_project_links.pop(0) # The first link is not a part of our data set.
        one_page_project_links_trimmed = one_page_project_links[0::2] # Every other link is a duplicate
        all_project_links.append(one_page_project_links_trimmed) # Add this page to the master list
        i += 1
    flat_list = [item for sublist in all_project_links for item in sublist] # Flatten the master list
    return flat_list

# %%
def examine_links (link_list):
    print('Links contained in list: ' + str(len(link_list)))
    if len(link_list) != 12*len(kickstarter_pages):
        print("Something went wrong, we didn't get the number of lists we expected!")
    else:
        print("Correct number of links detected!\n")
    for link in link_list:
        print(link)

# %%
campaign_url_list = get_data(kickstarter_pages) #  Returns a list of links which is 12*len(kickstarter_pages) long. 
examine_links(campaign_url_list) # Prints the full list of links and confirm that it is the correct length
# Out:
# Working on Page: 1
# Working on Page: 2
# Working on Page: 3
# Working on Page: 4
# Working on Page: 5
# Working on Page: 6
# Working on Page: 7
# Working on Page: 8
# Working on Page: 9
# Working on Page: 10
# Working on Page: 11
# Working on Page: 12
# Working on Page: 13
# Working on Page: 14
# Working on Page: 15
# Working on Page: 16
# Working on Page: 17
# Working on Page: 18
# Working on Page: 19
# Working on Page: 20
# Working on Page: 21
# Working on Page: 22
# Working on Page: 23
# Working on Page: 24
# Working on Page: 25
# Working on Page: 26
# Working on Page: 27
# Working on Page: 28
# Working on Page: 29
# Working on Page: 30
# Working on Page: 31
# Working on Page: 32
# Working on Page: 33
# Working on Page: 34
# Working on Page: 35
# Working on Page: 36
# Working on Page: 37
# Working on Page: 38
# Working on Page: 39
# Working on Page: 40
# Working on Page: 41
# Working on Page: 42
# Working on Page: 43
# Working on Page: 44
# Working on Page: 45
# Working on Page: 46
# Working on Page: 47
# Working on Page: 48
# Working on Page: 49
# Working on Page: 50
# Working on Page: 51
# Working on Page: 52
# Working on Page: 53
# Working on Page: 54
# Working on Page: 55
# Working on Page: 56
# Working on Page: 57
# Working on Page: 58
# Working on Page: 59
# Working on Page: 60
# Working on Page: 61
# Working on Page: 62
# Working on Page: 63
# Working on Page: 64
# Working on Page: 65
# Working on Page: 66
# Working on Page: 67
# Working on Page: 68
# Working on Page: 69
# Working on Page: 70
# Working on Page: 71
# Working on Page: 72
# Working on Page: 73
# Working on Page: 74
# Working on Page: 75
# Working on Page: 76
# Working on Page: 77
# Working on Page: 78
# Working on Page: 79
# Working on Page: 80
# Working on Page: 81
# Working on Page: 82
# Working on Page: 83
# Working on Page: 84
# Working on Page: 85
# Working on Page: 86
# Working on Page: 87
# Working on Page: 88
# Working on Page: 89
# Working on Page: 90
# Working on Page: 91
# Working on Page: 92
# Working on Page: 93
# Working on Page: 94
# Working on Page: 95
# Working on Page: 96
# Working on Page: 97
# Working on Page: 98
# Working on Page: 99
# Working on Page: 100
# Working on Page: 101
# Working on Page: 102
# Working on Page: 103
# Working on Page: 104
# Working on Page: 105
# Working on Page: 106
# Working on Page: 107
# Working on Page: 108
# Working on Page: 109
# Working on Page: 110
# Working on Page: 111
# Working on Page: 112
# Working on Page: 113
# Working on Page: 114
# Working on Page: 115
# Working on Page: 116
# Working on Page: 117
# Working on Page: 118
# Working on Page: 119
# Working on Page: 120
# Working on Page: 121
# Working on Page: 122
# Working on Page: 123
# Working on Page: 124
# Working on Page: 125
# Working on Page: 126
# Working on Page: 127
# Working on Page: 128
# Working on Page: 129
# Working on Page: 130
# Working on Page: 131
# Working on Page: 132
# Working on Page: 133
# Working on Page: 134
# Working on Page: 135
# Working on Page: 136
# Working on Page: 137
# Working on Page: 138
# Working on Page: 139
# Working on Page: 140
# Working on Page: 141
# Working on Page: 142
# Working on Page: 143
# Working on Page: 144
# Working on Page: 145
# Working on Page: 146
# Working on Page: 147
# Working on Page: 148
# Working on Page: 149
# Working on Page: 150
# Working on Page: 151
# Working on Page: 152
# Working on Page: 153
# Working on Page: 154
# Working on Page: 155
# Working on Page: 156
# Working on Page: 157
# Working on Page: 158
# Working on Page: 159
# Working on Page: 160
# Working on Page: 161
# Working on Page: 162
# Working on Page: 163
# Working on Page: 164
# Working on Page: 165
# Working on Page: 166
# Working on Page: 167
# Working on Page: 168
# Working on Page: 169
# Working on Page: 170
# Working on Page: 171
# Working on Page: 172
# Working on Page: 173
# Working on Page: 174
# Working on Page: 175
# Working on Page: 176
# Working on Page: 177
# Working on Page: 178
# Working on Page: 179
# Working on Page: 180
# Working on Page: 181
# Working on Page: 182
# Working on Page: 183
# Working on Page: 184
# Working on Page: 185
# Working on Page: 186
# Working on Page: 187
# Working on Page: 188
# Working on Page: 189
# Working on Page: 190
# Working on Page: 191
# Working on Page: 192
# Working on Page: 193
# Working on Page: 194
# Working on Page: 195
# Working on Page: 196
# Working on Page: 197
# Working on Page: 198
# Working on Page: 199
# Working on Page: 200

# %%
def scrape_vairables(project_soup, url):
    
    # How much money have they raised so far?
    raised_so_far = project_soup.find("div", class_='mb2-lg').text.splitlines()[2].replace(',', '')[1:]
    if raised_so_far == '':
        raised_so_far = project_soup.select_one("span[class*='green-700 inline-block js-convert_pledged medium type-16 type-24-md']").text.strip('\n')[1:].replace(',', '')
    raised_so_far = int(float(raised_so_far))
    
    # What was the total goal they are trying to reach?
    total_goal = int(project_soup.select_one("span[class*='block navy-600 type-12 type-14-md lh3-lg']").text[13:-6].replace(',', ''))

    # How many updates have they sent to their network through KS?
    updates_total = int(project_soup.find(attrs={'class' : 'js-load-project-content js-load-project-updates mx3 project-nav__link--updates tabbed-nav__link type-14'}).text[-2].replace(',', ''))

    # How many days remain in the campaign?
    remaining_time_html = project_soup.find_all("div", class_="poll ksr_page_timer")
    get_days_remaining = re.compile(r'data-end_time="[^"]+') # Establish our regex
    end_date_string = str(get_days_remaining.findall(str(remaining_time_html[1]))) # Apply the regex to pull the links we want
    end_date__string_cleaned = end_date_string[17:-8]
    campaign_end_date = datetime.strptime(end_date__string_cleaned, '%Y-%m-%dT%H:%M:%S')
    right_now = datetime.now()
    time_remaining = campaign_end_date - right_now
    days_remaining = int(time_remaining.days)

    # What was the campaign's title?
    title = project_soup.select_one("h2[class*='type-24 type-28-sm type-38-md navy-700 medium mb3']").text.strip('\n')

    # How many people have backed it so far?
    backers_count = int(project_soup.find(attrs={'id' : 'backers_count'}).text.strip('\n').replace(',', ''))

    # Was it an all-or-nothing campaign?
    all_or_nothing_text = project_soup.find(attrs={'class' : 'navy-700 pointer'}).text
    all_or_nothing = (all_or_nothing_text == "All or nothing.")

    # What Sub-Category was the campaign? 
    sub_category = project_soup.select_one("a[class*='nowrap navy-700 flex items-center medium mr3 type-12']").text.strip('\n')
    if sub_category == 'Project We Love':
        sub_category = project_soup.find_all("a", class_='nowrap navy-700 flex items-center medium mr3 type-12')[1].text.splitlines()[-1]
    
    # What Category was the campaign?
    all_categories = [['Art', 'Ceramics', 'Conceptual Art', 'Digital Art', 'Illustration', 'Installations', 'Mixed Media', 'Painting', 'Performance Art', 'Public Art', 'Sculpture', 'Textiles', 'Video Art'], 
                      ['Comics', 'Anthologies', 'Comic Books', 'Events', 'Graphic Novels', 'Webcomics'], 
                      ['Crafts', 'Candles', 'Crochet', 'DIY', 'Embroidery', 'Glass', 'Knitting', 'Pottery', 'Printing', 'Quilts', 'Stationery', 'Taxidermy', 'Weaving', 'Woodworking'], 
                      ['Dance', 'Performances', 'Residencies', 'Spaces', 'Workshops'], 
                      ['Design', 'Architecture', 'Civic Design', 'Graphic Design', 'Interactive Design', 'Product Design', 'Typography'], 
                      ['Fashion', 'Accessories', 'Apparel', 'Childrenswear', 'Couture', 'Footwear', 'Jewelry', 'Pet Fashion', 'Ready-to-wear'], 
                      ['Film_And_Video', 'Action', 'Animation', 'Comedy', 'Documentary', 'Drama', 'Experimental', 'Family', 'Fantasy', 'Festivals', 'Horror', 'Movie Theaters', 'Music Videos', 'Narrative Film', 'Romance', 'Science Fiction', 'Shorts', 'Television', 'Thrillers', 'Webseries'], 
                      ['Food', 'Bacon', 'Community Gardens', 'Cookbooks', 'Drinks', 'Events', "Farmer's Markets", 'Farms', 'Food Trucks', 'Restaurants', 'Small Batch', 'Spaces', 'Vegan'], 
                      ['Games', 'Gaming Hardware', 'Live Games', 'Mobile Games', 'Playing Cards', 'Puzzles', 'Tabletop Games', 'Video Games'], 
                      ['Journalism', 'Audio', 'Photo', 'Print', 'Video', 'Web'], 
                      ['Music', 'Blues', 'Chiptune', 'Classical Music', 'Comedy', 'Country & Folk', 'Electronic Music', 'Faith', 'Hip-Hop', 'Indie Rock', 'Jazz', 'Kids', 'Latin', 'Metal', 'Pop', 'Punk', 'R&B', 'Rock', 'World Music'], 
                      ['Photography', 'Animals', 'Fine Art', 'Nature', 'People', 'Photobooks', 'Places'], 
                      ['Publishing', 'Academic', 'Anthologies', 'Art Books', 'Calendars', "Children's Books", 'Comedy', 'Fiction', 'Letterpress', 'Literary Journals', 'Nonfiction', 'Periodicals', 'Poetry', 'Radio & Podcasts', 'Translations', 'Young Adult', 'Zines', 'Literary Spaces'], 
                      ['Technology', '3D Printing', 'Apps', 'Camera Equipment', 'DIY Electronics', 'Fabrication Tools', 'Flight', 'Gadgets', 'Hardware', 'Makerspaces', 'Robots', 'Software', 'Sound', 'Space Exploration', 'Wearables', 'Web'], 
                      ['Theater', 'Comedy', 'Experimental', 'Festivals', 'Immersive', 'Musical', 'Plays', 'Spaces']]
    category = [cat[0] for cat in all_categories if sub_category in cat]

    # How long was the title? 
    title_length = len(title) # how long title in characters

    # What is the total number of tiers
    tier_count = len(project_soup.find_all("div", class_='pledge__info')) - 1

    # Is there a video? 
    video_contents = project_soup.find("video", class_='has_hls landscape')
    if not video_contents: 
        contains_video = False
    else:
        contains_video = True

    # How many images are on the page?
    number_images = len(project_soup.find_all("div", class_='template asset'))


    # How much text is on the page? 
    all_page_paragraphs = project_soup.find_all("p")
    page_text = [item.text for item in all_page_paragraphs]
    flattened_page_text = ''.join(page_text)
    total_text = len(flattened_page_text)

    data = [title, url, total_goal, raised_so_far, backers_count, days_remaining, number_images, contains_video, tier_count, updates_total, title_length, category, sub_category, all_or_nothing, total_text] # incomplete
    return data

# %%
# Starting with a shorter list of URLs
short_list = campaign_url_list[0:2400]
# Note, if any of the campaigns in campaign_url_list finished while we were scraping then their format will have changed and they will throw errors.  This is why, later on, we'll see several different dataframes concatenated into one.  Each is separated by an error.  
#def scrape_in_sequence(short_list):
url1 = 'www.kickstarter.com/projects/1227872561/unbroken-a-solo-game-of-survival-and-revenge'
url2 = 'http://www.kickstarter.com/projects/1227872561/unbroken-a-solo-game-of-survival-and-revenge'
scrape_store = {}
i = 0
data_headers = ['title', 'URL','total_goal', 'raised_so_far', 'backers_count', 'days_remaining', 'number_images', 'contains_video', 'tier_count', 'updates_total', 'title_length', 'category', 'sub_category', 'all_or_nothing', 'total_text']
df = pd.DataFrame(columns=data_headers)
for url in short_list:
    project_response = requests.get('http://' + url) 
    project_page = project_response.text
    scrape_store[i] = [url, project_page]
    project_soup = BeautifulSoup(project_page,"lxml")
    i += 1
    time.sleep(.5 + random.random())
    one_page_features = scrape_vairables(project_soup, url)
    df = df.append(pd.Series(one_page_features, index=data_headers), ignore_index=True)

    print('Sraping page: ' + str(i))
with open('all_scrapes.csv', 'w') as csv_file:
    writer = csv.writer(csv_file)
    for key, value in scrape_store.items():
        writer.writerow([key, value])
        

#Response variable is %of planned $s pledged
# Out:
# Sraping page: 1
# Sraping page: 2
# Sraping page: 3
# Sraping page: 4
# Sraping page: 5
# Sraping page: 6
# Sraping page: 7
# Sraping page: 8
# Sraping page: 9
# Sraping page: 10
# Sraping page: 11
# Sraping page: 12
# Sraping page: 13
# Sraping page: 14
# Sraping page: 15
# Sraping page: 16
# Sraping page: 17
# Sraping page: 18
# Sraping page: 19
# Sraping page: 20
# Sraping page: 21
# Sraping page: 22
# Sraping page: 23
# Sraping page: 24
# Sraping page: 25
# Sraping page: 26
# Sraping page: 27
# Sraping page: 28
# Sraping page: 29
# Sraping page: 30
# Sraping page: 31
# Sraping page: 32
# Sraping page: 33
# Sraping page: 34
# Sraping page: 35
# Sraping page: 36
# Sraping page: 37
# Sraping page: 38
# Sraping page: 39
# Sraping page: 40
# Sraping page: 41
# Sraping page: 42
# Sraping page: 43
# Sraping page: 44
# Sraping page: 45
# Sraping page: 46
# Sraping page: 47
# Sraping page: 48
# Sraping page: 49
# Sraping page: 50
# Sraping page: 51
# Sraping page: 52
# Sraping page: 53
# Sraping page: 54
# Sraping page: 55
# Sraping page: 56
# Sraping page: 57
# Sraping page: 58
# Sraping page: 59
# Sraping page: 60
# Sraping page: 61
# Sraping page: 62
# Sraping page: 63
# Sraping page: 64
# Sraping page: 65
# Sraping page: 66
# Sraping page: 67
# Sraping page: 68
# Sraping page: 69
# Sraping page: 70
# Sraping page: 71
# Sraping page: 72
# Sraping page: 73
# Sraping page: 74
# Sraping page: 75
# Sraping page: 76
# Sraping page: 77
# Sraping page: 78
# Sraping page: 79
# Sraping page: 80
# Sraping page: 81
# Sraping page: 82
# Sraping page: 83
# Sraping page: 84
# Sraping page: 85
# Sraping page: 86
# Sraping page: 87
# Sraping page: 88
# Sraping page: 89
# Sraping page: 90
# Sraping page: 91
# Sraping page: 92
# Sraping page: 93
# Sraping page: 94
# Sraping page: 95
# Sraping page: 96
# Sraping page: 97
# Sraping page: 98
# Sraping page: 99
# Sraping page: 100
# Sraping page: 101
# Sraping page: 102
# Sraping page: 103
# Sraping page: 104
# Sraping page: 105
# Sraping page: 106
# Sraping page: 107
# Sraping page: 108
# Sraping page: 109
# Sraping page: 110
# Sraping page: 111
# Sraping page: 112
# Sraping page: 113
# Sraping page: 114
# Sraping page: 115
# Sraping page: 116
# Sraping page: 117
# Sraping page: 118
# Sraping page: 119
# Sraping page: 120
# Sraping page: 121
# Sraping page: 122
# Sraping page: 123
# Sraping page: 124
# Sraping page: 125
# Sraping page: 126
# Sraping page: 127
# Sraping page: 128
# Sraping page: 129
# Sraping page: 130
# Sraping page: 131
# Sraping page: 132
# Sraping page: 133
# Sraping page: 134
# Sraping page: 135
# Sraping page: 136
# Sraping page: 137
# Sraping page: 138
# Sraping page: 139
# Sraping page: 140
# Sraping page: 141
# Sraping page: 142
# Sraping page: 143
# Sraping page: 144
# Sraping page: 145
# Sraping page: 146
# Sraping page: 147
# Sraping page: 148
# Sraping page: 149
# Sraping page: 150
# Sraping page: 151
# Sraping page: 152
# Sraping page: 153
# Sraping page: 154
# Sraping page: 155
# Sraping page: 156
# Sraping page: 157
# Sraping page: 158
# Sraping page: 159
# Sraping page: 160
# Sraping page: 161
# Sraping page: 162
# Sraping page: 163
# Sraping page: 164
# Sraping page: 165
# Sraping page: 166
# Sraping page: 167
# Sraping page: 168
# Sraping page: 169
# Sraping page: 170
# Sraping page: 171
# Sraping page: 172
# Sraping page: 173
# Sraping page: 174
# Sraping page: 175
# Sraping page: 176
# Sraping page: 177
# Sraping page: 178
# Sraping page: 179
# Sraping page: 180
# Sraping page: 181
# Sraping page: 182
# Sraping page: 183
# Sraping page: 184
# Sraping page: 185
# Sraping page: 186
# Sraping page: 187
# Sraping page: 188
# Sraping page: 189
# Sraping page: 190
# Sraping page: 191
# Sraping page: 192
# Sraping page: 193
# Sraping page: 194
# Sraping page: 195
# Sraping page: 196
# Sraping page: 197
# Sraping page: 198
# Sraping page: 199
# Sraping page: 200
# Sraping page: 201
# Sraping page: 202
# Sraping page: 203
# Sraping page: 204
# Sraping page: 205
# Sraping page: 206
# Sraping page: 207
# Sraping page: 208
# Sraping page: 209
# Sraping page: 210
# Sraping page: 211
# Sraping page: 212
# Sraping page: 213
# Sraping page: 214
# Sraping page: 215
# Sraping page: 216
# Sraping page: 217
# Sraping page: 218
# Sraping page: 219
# Sraping page: 220
# Sraping page: 221
# Sraping page: 222
# Sraping page: 223
# Sraping page: 224
# Sraping page: 225
# Sraping page: 226
# Sraping page: 227
# Sraping page: 228
# Sraping page: 229
# Sraping page: 230
# Sraping page: 231
# Sraping page: 232
# Sraping page: 233
# Sraping page: 234
# Sraping page: 235
# Sraping page: 236
# Sraping page: 237
# Sraping page: 238
# Sraping page: 239
# Sraping page: 240
# Sraping page: 241
# Sraping page: 242
# Sraping page: 243
# Sraping page: 244
# Sraping page: 245
# Sraping page: 246
# Sraping page: 247
# Sraping page: 248
# Sraping page: 249
# Sraping page: 250
# Sraping page: 251
# Sraping page: 252
# Sraping page: 253
# Sraping page: 254
# Sraping page: 255
# Sraping page: 256
# Sraping page: 257
# Sraping page: 258
# Sraping page: 259
# Sraping page: 260
# Sraping page: 261
# Sraping page: 262
# Sraping page: 263
# Sraping page: 264
# Sraping page: 265
# Sraping page: 266
# Sraping page: 267
# Sraping page: 268
# Sraping page: 269
# Sraping page: 270
# Sraping page: 271
# Sraping page: 272
# Sraping page: 273
# Sraping page: 274
# Sraping page: 275
# Sraping page: 276
# Sraping page: 277
# Sraping page: 278
# Sraping page: 279
# Sraping page: 280
# Sraping page: 281
# Sraping page: 282
# Sraping page: 283
# Sraping page: 284
# Sraping page: 285
# Sraping page: 286
# Sraping page: 287
# Sraping page: 288
# Sraping page: 289
# Sraping page: 290
# Sraping page: 291
# Sraping page: 292
# Sraping page: 293
# Sraping page: 294
# Sraping page: 295
# Sraping page: 296
# Sraping page: 297
# Sraping page: 298
# Sraping page: 299
# Sraping page: 300
# Sraping page: 301
# Sraping page: 302
# Sraping page: 303
# Sraping page: 304
# Sraping page: 305
# Sraping page: 306
# Sraping page: 307
# Sraping page: 308
# Sraping page: 309
# Sraping page: 310
# Sraping page: 311
# Sraping page: 312
# Sraping page: 313
# Sraping page: 314
# Sraping page: 315
# Sraping page: 316
# Sraping page: 317
# Sraping page: 318
# Sraping page: 319
# Sraping page: 320
# Sraping page: 321
# Sraping page: 322
# Sraping page: 323
# Sraping page: 324
# Sraping page: 325

# %%
kickstarter_data = df1.append(df2)        
kickstarter_data = kickstarter_data.append(df3)        
kickstarter_data = kickstarter_data.append(df4)        
kickstarter_data = kickstarter_data.append(df5)        
kickstarter_data = kickstarter_data.append(df6)        

print(df1.shape)
print(df2.shape)
print(df3.shape)
print(df4.shape)
print(df5.shape)
print(df6.shape)

print(kickstarter_data.shape)
kickstarter_data.sample(20)
# Out:
# (448, 15)
# (910, 15)
# (343, 15)
# (143, 15)
# (225, 15)
# (325, 15)
# (2394, 15)
#                                                  title  \
# 442  CubeYourLife! One Cube 80 games to Play Togeth...
# 477  Pleasure Boat Studio: A Literary Press, a book...
# 142  Physical Skycoin Limited Edition Collectable Coin
# 432                               Bad Mouth Party Game
# 160  Responsible Firearm Programs From Top Master I...
# 291  GEORGE® THE WORLD'S BEST ARMATURE FOR STOP MOT...
# 858            Hollow Monsters: WHO IS THE HOLLOW MAN?
# 74   Zeno™ | Italian Design meets Non-Iron & No-Sta...
# 816            Save the Kestrel! They need nest boxes.
# 862    The Cityscape Table - Inspired by Iconic Cities
# 663                                        100 Cameras
# 259        Lotushirt: The STAINLESS wrinkle free shirt
# 202  Conquering Your Teen Years - Motivational Surv...
# 324                  Adorned by Chi: The Graphic Novel
# 69   Move a Giant Iron Horse to Porter Sculpture Park!
# 90    "Suggestivism: Resonance" coffee table art book!
# 321  European Adventure: 1944 to 1945 WWII Memoir a...
# 300  Sidekicks: Extraordinary Force of Ordinary People
# 134  enLIGHTen Clock - The World's Most Customizabl...
# 243                            GREAT PASSION FOR MUSIC
#
#                                                    URL total_goal  \
# 442  www.kickstarter.com/projects/1207576737/cube-y...      24446
# 477  www.kickstarter.com/projects/1678535734/pleasu...       5000
# 142  www.kickstarter.com/projects/293386705/physica...       7333
# 432  www.kickstarter.com/projects/jaysterbaby/bad-m...       7790
# 160  www.kickstarter.com/projects/1689485012/respon...     122000
# 291  www.kickstarter.com/projects/973708455/george-...       3178
# 858  www.kickstarter.com/projects/1435105183/hollow...       2796
# 74   www.kickstarter.com/projects/zenoshirt/zenotm-...      12223
# 816  www.kickstarter.com/projects/621619349/save-th...        500
# 862  www.kickstarter.com/projects/agardc/the-citysc...       1887
# 663  www.kickstarter.com/projects/livinginthefutr/1...       1168
# 259  www.kickstarter.com/projects/454615361/lotushi...       9939
# 202  www.kickstarter.com/projects/722440849/conquer...        500
# 324  www.kickstarter.com/projects/1314985923/adorne...      15000
# 69   www.kickstarter.com/projects/wayneporter/move-...      15000
# 90   www.kickstarter.com/projects/1022634580/sugges...      10000
# 321  www.kickstarter.com/projects/1214471054/europe...       1000
# 300  www.kickstarter.com/projects/1865913408/sideki...       2500
# 134  www.kickstarter.com/projects/1926284625/enligh...       3000
# 243  www.kickstarter.com/projects/299697779/great-p...       5871
#
#     raised_so_far backers_count days_remaining number_images contains_video  \
# 442          9733           148             23            67           True
# 477           325             6              3             0           True
# 142          7272            50             15             4          False
# 432           222             9             19             6           True
# 160           310             5             51            12           True
# 291          8025            46             50            73           True
# 858          3478           108             15            34          False
# 74          16066           109              0            29           True
# 816           110             4             12             0           True
# 862           461             2              5            25           True
# 663             3             1             38             5          False
# 259         26602           319             37            26          False
# 202             5             1              1             0          False
# 324         11884           331             10            10           True
# 69          12693           124             10            10           True
# 90          13604           164             22             5          False
# 321           933            20              9             3          False
# 300             0             0             59             4           True
# 134          2218            14             20            15           True
# 243             0             0              1             0          False
#
#     tier_count updates_total title_length       category    sub_category  \
# 442         12             3           59        [Games]           Games
# 477          1             0           59   [Publishing]      Publishing
# 142         12             4           49   [Technology]         Gadgets
# 432          5             2           20        [Games]  Tabletop Games
# 160          8             0           56   [Publishing]      Publishing
# 291         11             3           59       [Design]  Product Design
# 858         14             2           39       [Comics]          Comics
# 74          10             3           59      [Fashion]         Apparel
# 816          7             0           39       [Crafts]     Woodworking
# 862          6             1           47       [Design]  Product Design
# 663          6             0           11  [Photography]     Photography
# 259          4             2           43   [Technology]       Wearables
# 202          1             0           56   [Publishing]     Young Adult
# 324         10             1           33       [Comics]  Graphic Novels
# 69           8             1           49          [Art]       Sculpture
# 90           4             0           48   [Publishing]       Art Books
# 321          8             1           58   [Publishing]      Nonfiction
# 300          3             0           49      [Fashion]         Apparel
# 134          6             2           53   [Technology]        Hardware
# 243          1             0           23        [Music]           Music
#
#     all_or_nothing total_text
# 442           True       8267
# 477           True       2531
# 142           True      10787
# 432           True       5046
# 160           True      12225
# 291           True      13676
# 858           True      10583
# 74            True       8268
# 816           True       5970
# 862           True       5232
# 663           True       3601
# 259           True       6225
# 202           True       2194
# 324           True       5809
# 69            True       5243
# 90            True       5246
# 321           True       3957
# 300           True       2427
# 134           True       8721
# 243           True       2043

# %%
with open('kickstarter_data_pickle.pkl', 'wb') as picklefile:
    pickle.dump(kickstarter_data, picklefile)
